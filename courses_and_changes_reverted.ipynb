# %% [markdown]
# ## courses + new changes
#
# - run entire notebook, the very last function is called `do_everything()`. to get, say, ECON course changes, just run `do_everything('ECON')`
#
# the following are hard-coded (will need to be updated in future years):
# - the base URL that everything begins from
# - typing 20182019 and 20192020 (eg next year change to 20192020 and 20202021)
#
# june 26, 2019

# %%
# autumn + winter + spring courses for 2018-2019
BASE_PAGE_URL = 'https://explorecourses.stanford.edu/search?q=LINGUIST&view=catalog&filter-term-Winter=on&filter-departmentcode-LINGUIST=on&filter-catalognumber-LINGUIST=on&academicYear=20182019&filter-term-Autumn=on&filter-term-Spring=on&page=0&filter-coursestatus-Active=on&collapse='

# %%
from bs4 import BeautifulSoup
from subprocess import check_output

# %%
def get_n_pages(pgs):
    lst = []
    for x in pgs:
        try:
            lst.append(int(x))
        except:
            pass
    return max(lst)

def get_search_results_on_page(url, year, ith):
    print('Pulling page', ith + 1)
    new_url = url.replace('page=0', 'page=' + str(ith))
    new_src = check_output([
        'wget',
        '-qO-',
        new_url
    ])
    parse = BeautifulSoup(new_src)
    return parse.body.find(
        'div',
        attrs={'id': 'searchResults'}
    )
    
def get_results_list(url, year='20182019'):
    src = check_output([
        'wget',
        '-qO-',
        url
    ])
    parse = BeautifulSoup(src)
    n_pages = get_n_pages(parse.body.find(
        'div',
        attrs={'id': 'pagination'}
    ).text.split())
    print('Need to scrape', n_pages, 'pages')
    to_return = [get_search_results_on_page(url, year, ith) for ith in range(n_pages)]
    print('Scraping done!')
    return to_return

# %%
results_list = get_results_list(BASE_PAGE_URL)
# Out:
# Need to scrape 7 pages
# Pulling page 1
# Pulling page 2
# Pulling page 3
# Pulling page 4
# Pulling page 5
# Pulling page 6
# Pulling page 7
# Scraping done!

# %%
legal_fields = {
    'Terms',
    'Units',
    'UG Reqs',
    'Grading',
}

def extract_data(fields):
    relevant_name_to_val = {}
    for item in fields:
        idx = item.find(':')
        field_name = item[:idx]
        if field_name in legal_fields:
            field_val = item[idx + 1:].strip()
            relevant_name_to_val[field_name] = field_val
    return relevant_name_to_val

def fetch_info(course, mp):
    code = course.find(
        'span',
        attrs={'class': 'courseNumber'}
    ).text.strip(':')
    mp[code] = {}
    name = course.find(
        'span',
        attrs={'class': 'courseTitle'}
    ).text
    mp[code]['Title'] = name
    
    attribs = course.find(
        'div',
        attrs={'class': 'courseAttributes'}
    ).text
    fields = [x.strip() for x in ' '.join(attribs.split()).split('|')]
    extracted = extract_data(fields)    
    for field in legal_fields:
        if field in extracted:
            mp[code][field] = extracted[field]
        else:
            mp[code][field] = None

def parse_results_list(results_list):
    print('Parsing . . .')
    course_to_field_to_info_map_map = {}
    for results in results_list:
        all_courses = results.findAll(
            'div',
            attrs={'class': 'courseInfo'}
        )
        for course in all_courses:
            fetch_info(course, course_to_field_to_info_map_map)
    print('Parsing done!')
    return course_to_field_to_info_map_map

# %%
ling_20182019 = parse_results_list(results_list)
# Out:
# Parsing . . .
# Parsing done!

# %%
url_20192020 = BASE_PAGE_URL.replace('20182019', '20192020')
ling_20192020 = parse_results_list(get_results_list(url_20192020))
# Out:
# Need to scrape 7 pages
# Pulling page 1
# Pulling page 2
# Pulling page 3
# Pulling page 4
# Pulling page 5
# Pulling page 6
# Pulling page 7
# Scraping done!
# Parsing . . .
# Parsing done!

# %%
import re
from termcolor import cprint

fields = [
    'Title',
    'Terms',
    'Units',
    'UG Reqs',
    'Grading'
]

# stackoverflow Mark Byers
def natural_sort(l): 
    convert = lambda text: int(text) if text.isdigit() else text.lower() 
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(l, key = alphanum_key)

def find_differences(A, B, a, b):
    print('Courses in ' + a + ' but not in ' + b + ':')
    for course in A:
        if course not in B:
            cprint(' - ' + course + '\n   - ' + A[course]['Title'], attrs=['bold'])
    print('\n')
    print('Courses in ' + b + ' but not in ' + a + ':')
    for course in B:
        if course not in A:
            cprint(' - ' + course + '\n   - ' + B[course]['Title'] + ' (' + B[course]['Terms'] + ')', attrs=['bold'])
    print('\nCourses Retained:')
    overlap = A.keys() & B.keys()
    for course in natural_sort(overlap):
        cprint(' - ' + course, attrs=['bold'])
        for f in fields:
            print('    ' + f + ': ', end=' ')
            if f not in A[course] or f not in B[course]:
                if f not in A[course]:
                    cprint('None', 'red', attrs=['bold'])
                else:
                    cprint(A[course], 'red', attrs=['bold'])
                if f not in B[course]:
                    cprint('None', 'green', attrs=['bold'])
                else:
                    cprint(B[course], 'green', attrs=['bold'])
            elif A[course][f] != B[course][f]:
                cprint(A[course][f], 'red', end=' ', attrs=['bold'])
                cprint(B[course][f], 'green', attrs=['bold'])
            else:
                print(A[course][f])

# %%
find_differences(ling_20182019, ling_20192020, 'Ling 18-19', 'Ling 19-20')
# Out:
# Courses in Ling 18-19 but not in Ling 19-20:
#  - LINGUIST 55N
#    - Language in the City
#  - LINGUIST 65
#    - African American Vernacular English (AFRICAAM 21, CSRE 21, LINGUIST 265)
#  - LINGUIST 83Q
#    - Translation
#  - LINGUIST 121A
#    - The Syntax of English
#  - LINGUIST 152
#    - Sociolinguistics and Pidgin Creole Studies (LINGUIST 252)
#  - LINGUIST 157
#    - Sociophonetics (LINGUIST 257)
#  - LINGUIST 160
#    - Introduction to Language Change
#  - LINGUIST 200
#    - Foundations of Linguistic Theory
#  - LINGUIST 207A
#    - Advanced Phonetics
#  - LINGUIST 211
#    - Metrics
#  - LINGUIST 225
#    - Seminar in Syntax: Distributed Morphology
#  - LINGUIST 236
#    - Seminar in Semantics: Causation
#  - LINGUIST 247
#    - Seminar in Psycholinguistics: Advanced Topics (PSYCH 227)
#  - LINGUIST 250
#    - Sociolinguistic Theory and Analysis
#  - LINGUIST 252
#    - Sociolinguistics and Pidgin Creole Studies (LINGUIST 152)
#  - LINGUIST 257
#    - Sociophonetics (LINGUIST 157)
#  - LINGUIST 265
#    - African American Vernacular English (AFRICAAM 21, CSRE 21, LINGUIST 65)
#  - LINGUIST 272
#    - Structure of Finnish
#  - LINGUIST 286
#    - Information Retrieval and Web Search (CS 276)
#
#
# Courses in Ling 19-20 but not in Ling 18-19:
#  - LINGUIST 54N
#    - Social Bias and Earwitness Memory (Aut)
#  - LINGUIST 121B
#    - Crosslinguistic Syntax (Aut)
#  - LINGUIST 132
#    - Lexical Semantic Typology (Aut)
#  - LINGUIST 167
#    - Languages of the World (Spr)
#  - LINGUIST 207L
#    - Phonetics Research Lab (Aut, Win, Spr)
#  - LINGUIST 210B
#    - Advanced Phonology (Win)
#  - LINGUIST 217
#    - Morphosyntax (Spr)
#  - LINGUIST 232B
#    - Seminar in Lexical Semantics:  Lexical semantic typology (Win)
#  - LINGUIST 247L
#    - Alps Research Lab (Aut, Win, Spr)
#  - LINGUIST 257L
#    - Interactional Phonetics Research Lab (Aut, Win, Spr)
#  - LINGUIST 258
#    - Analysis of Variation (Win)
#  - LINGUIST 258A
#    - Variation and Social Meaning (Aut)
#  - LINGUIST 260A
#    - Historical Morphology and Phonology (Aut)
#  - LINGUIST 289L
#    - Computational Linguistics Research Labl (Aut, Win, Spr)
#
# Courses Retained:
#  - LINGUIST 1
#     Title:  Introduction to Linguistics
#     Terms:  Aut
#     Units:  4
#     UG Reqs:  GER:DB-SocSci, WAY-SI
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 30N
#     Title:  Linguistic Meaning and the Law
#     Terms:  Win
#     Units:  3
#     UG Reqs:  WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 35
#     Title:  Minds and Machines (PHIL 99, PSYCH 35, SYMSYS 1, SYMSYS 200)
#     Terms:  Win, Sum Aut, Sum
#     Units:  4
#     UG Reqs:  GER:DB-SocSci, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 47N
#     Title:  Languages, Dialects, Speakers
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  GER:DB-SocSci
#     Grading:  Letter (ABCD/NP)
#  - LINGUIST 90
#     Title:  Teaching Spoken English
#     Terms:  Spr
#     Units:  3-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 105
#     Title:  Phonetics (LINGUIST 205A)
#     Terms:  Win
#     Units:  4
#     UG Reqs:  GER:DB-SocSci, WAY-SMA
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 110
#     Title:  Introduction to Phonology
#     Terms:  Aut Win
#     Units:  4
#     UG Reqs:  GER:DB-SocSci, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 130A
#     Title:  Introduction to Semantics and Pragmatics (LINGUIST 230A)
#     Terms:  Win
#     Units:  4
#     UG Reqs:  GER:DB-SocSci, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 130B
#     Title:  Introduction to Lexical Semantics
#     Terms:  Spr
#     Units:  3-4
#     UG Reqs:  GER:DB-SocSci, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 145
#     Title:  Introduction to Psycholinguistics (LINGUIST 245A, PSYCH 140)
#     Terms:  Aut
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 150
#     Title:  Language and Society
#     Terms:  Aut Win
#     Units:  4
#     UG Reqs:  GER:DB-SocSci, WAY-ED, WAY-SI
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 156
#     Title:  Language and Gender (FEMGEN 156X)
#     Terms:  Win Aut
#     Units:  4
#     UG Reqs:  GER:DB-SocSci, GER:EC-Gender, WAY-ED, WAY-SI
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 180
#     Title:  From Languages to Information (CS 124, LINGUIST 280)
#     Terms:  Win
#     Units:  3-4
#     UG Reqs:  WAY-AQR
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 188
#     Title:  Natural Language Understanding (CS 224U, LINGUIST 288)
#     Terms:  Spr
#     Units:  3-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 191
#     Title:  Linguistics and the Teaching of English as a Second/Foreign Language (LINGUIST 291)
#     Terms:  Win
#     Units:  4-5
#     UG Reqs:  GER:DB-SocSci
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 195A
#     Title:  Undergraduate Research Workshop
#     Terms:  Win, Spr
#     Units:  1
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - LINGUIST 196
#     Title:  Introduction to Research for Undergraduates
#     Terms:  Aut
#     Units:  1
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - LINGUIST 197A
#     Title:  Undergraduate Research Seminar
#     Terms:  Win
#     Units:  2-3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 198
#     Title:  Honors Research
#     Terms:  Aut, Win, Spr
#     Units:  1-15
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 199
#     Title:  Independent Study
#     Terms:  Aut, Win, Spr, Sum
#     Units:  1-15
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 205A
#     Title:  Phonetics (LINGUIST 105)
#     Terms:  Win
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 210A
#     Title:  Phonology
#     Terms:  Spr Aut
#     Units:  3-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 222A
#     Title:  Foundations of Syntactic Theory I
#     Terms:  Aut
#     Units:  3-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 222B
#     Title:  Foundations of Syntactic Theory II
#     Terms:  Win
#     Units:  3-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 225S
#     Title:  Syntax and Morphology Research Seminar
#     Terms:  Aut, Win, Spr
#     Units:  1
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - LINGUIST 230A
#     Title:  Introduction to Semantics and Pragmatics (LINGUIST 130A)
#     Terms:  Win
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 230B
#     Title:  Semantics and Pragmatics I
#     Terms:  Spr
#     Units:  2-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 230C
#     Title:  Semantics and Pragmatics II
#     Terms:  Aut
#     Units:  1-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 232A
#     Title:  Lexical Semantics
#     Terms:  Aut
#     Units:  2-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 245A
#     Title:  Introduction to Psycholinguistics (LINGUIST 145, PSYCH 140)
#     Terms:  Aut
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 245B
#     Title:  Methods in Psycholinguistics
#     Terms:  Spr
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 255A
#     Title:  Seminar in Sociolinguistics: California Dialectology
#     Terms:  Aut
#     Units:  2-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 255L
#     Title:  Seminar in Sociolinguistics: Multiracial Identity in Variation Studies
#     Terms:  Spr
#     Units:  1-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 260B
#     Title:  Historical Morphosyntax
#     Terms:  Spr
#     Units:  2-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 278
#     Title:  Programming for Linguists
#     Terms:  Aut
#     Units:  1-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 280
#     Title:  From Languages to Information (CS 124, LINGUIST 180)
#     Terms:  Win
#     Units:  3-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 284
#     Title:  Natural Language Processing with Deep Learning (CS 224N)
#     Terms:  Win
#     Units:  3-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 288
#     Title:  Natural Language Understanding (CS 224U, LINGUIST 188)
#     Terms:  Spr
#     Units:  3-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 291
#     Title:  Linguistics and the Teaching of English as a Second/Foreign Language (LINGUIST 191)
#     Terms:  Win
#     Units:  4-5
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 294
#     Title:  Linguistic Research Discussion Group
#     Terms:  Aut
#     Units:  1
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - LINGUIST 390
#     Title:  M.A. Project
#     Terms:  Aut, Win, Spr, Sum
#     Units:  1-6
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 391A
#     Title:  Curricular Practical Training
#     Terms:  Aut, Sum
#     Units:  1
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - LINGUIST 394
#     Title:  TA Training Workshop
#     Terms:  Aut
#     Units:  1
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - LINGUIST 395
#     Title:  Research Workshop
#     Terms:  Spr
#     Units:  1-2
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - LINGUIST 396
#     Title:  Research Projects in Linguistics
#     Terms:  Win
#     Units:  2-3
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - LINGUIST 397
#     Title:  Directed Reading
#     Terms:  Aut, Win, Spr, Sum
#     Units:  1-15
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 398
#     Title:  Directed Research
#     Terms:  Aut, Win, Spr, Sum
#     Units:  1-15
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - LINGUIST 399
#     Title:  Dissertation Research
#     Terms:  Aut, Win, Spr, Sum
#     Units:  1-15
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit

# %%
def do_everything(dept_code):
    url = BASE_PAGE_URL.replace('LINGUIST', dept_code)
    url_2 = url.replace('20182019', '20192020')
    a = parse_results_list(get_results_list(url))
    b = parse_results_list(get_results_list(url_2))
    find_differences(a, b, dept_code + ' 18-19', dept_code + ' 19-20')

# %%
do_everything('CS')
# Out:
# Need to scrape 21 pages
# Pulling page 1
# Pulling page 2
# Pulling page 3
# Pulling page 4
# Pulling page 5
# Pulling page 6
# Pulling page 7
# Pulling page 8
# Pulling page 9
# Pulling page 10
# Pulling page 11
# Pulling page 12
# Pulling page 13
# Pulling page 14
# Pulling page 15
# Pulling page 16
# Pulling page 17
# Pulling page 18
# Pulling page 19
# Pulling page 20
# Pulling page 21
# Scraping done!
# Parsing . . .
# Parsing done!
# Need to scrape 20 pages
# Pulling page 1
# Pulling page 2
# Pulling page 3
# Pulling page 4
# Pulling page 5
# Pulling page 6
# Pulling page 7
# Pulling page 8
# Pulling page 9
# Pulling page 10
# Pulling page 11
# Pulling page 12
# Pulling page 13

# %%
do_everything('MATH')
# Out:
# Courses in MATH 18-19 but not in MATH 19-20:
#  - MATH 137
#    - Mathematical Methods of Classical Mechanics
#  - MATH 145
#    - Algebraic Geometry
#  - MATH 148
#    - Algebraic Topology
#  - MATH 154
#    - Algebraic Number Theory
#  - MATH 161
#    - Set Theory
#  - MATH 234
#    - Large Deviations Theory (STATS 374)
#  - MATH 235A
#    - Topics in combinatorics
#  - MATH 237A
#    - Topics in Financial Math: Market microstructure and trading algorithms
#  - MATH 256B
#    - Partial Differential Equations
#  - MATH 257C
#    - Symplectic Geometry and Topology
#  - MATH 263C
#    - Topics in Representation Theory
#  - MATH 273
#    - Topics in Mathematical Physics (STATS 359)
#  - MATH 275
#    - Topics in Applied Mathematics: A World of Flows
#  - MATH 305
#    - Applied mathematics through toys and magic
#
#
# Courses in MATH 19-20 but not in MATH 18-19:
#  - MATH 142
#    - Hyperbolic Geometry (Spr)
#  - MATH 147
#    - Differential Topology (Aut)
#  - MATH 155
#    - Analytic Number Theory (Spr)
#  - MATH 173
#    - Theory of Partial Differential Equations (Win)
#  - MATH 177
#    - Geometric Methods in the Theory of Ordinary Differential Equations (Win)
#  - MATH 205C
#    - Real Analysis (Spr)
#  - MATH 216A
#    - Introduction to Algebraic Geometry (Aut)
#  - MATH 216B
#    - Introduction to Algebraic Geometry (Win)
#  - MATH 233C
#    - Topics in Combinatorics (Spr)
#  - MATH 235B
#    - Modern Markov Chain Theory (Spr)
#  - MATH 249C
#    - Topics in Number Theory (Spr)
#  - MATH 257A
#    - Symplectic Geometry and Topology (Aut)
#  - MATH 257B
#    - Symplectic Geometry and Topology (Win)
#  - MATH 258
#    - Topics in Geometric Analysis (Win)
#  - MATH 286
#    - Topics in Differential Geometry (Win)
#
# Courses Retained:
#  - MATH 19
#     Title:  Calculus
#     Terms:  Aut, Win, Sum
#     Units:  3
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 20
#     Title:  Calculus
#     Terms:  Aut, Win, Spr
#     Units:  3
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 21
#     Title:  Calculus
#     Terms:  Aut, Win, Spr
#     Units:  4
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 21A
#     Title:  Calculus, ACE
#     Terms:  Aut, Win, Spr
#     Units:  5
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 51
#     Title:  Linear Algebra, Multivariable Calculus, and Modern Applications
#     Terms:  Aut, Win, Spr, Sum
#     Units:  5
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 51A
#     Title:  Linear Algebra, Multivariable Calculus, and Modern Applications, ACE
#     Terms:  Aut, Win, Spr
#     Units:  6
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 52
#     Title:  Integral Calculus of Several Variables
#     Terms:  Aut, Win, Spr
#     Units:  5
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 53
#     Title:  Ordinary Differential Equations with Linear Algebra
#     Terms:  Aut, Win, Spr, Sum
#     Units:  5
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 61CM
#     Title:  Modern Mathematics: Continuous Methods
#     Terms:  Aut
#     Units:  5
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 61DM
#     Title:  Modern Mathematics: Discrete Methods
#     Terms:  Aut
#     Units:  5
#     UG Reqs:  WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 62CM
#     Title:  Modern Mathematics: Continuous Methods
#     Terms:  Win
#     Units:  5
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter (ABCD/NP)
#  - MATH 62DM
#     Title:  Modern Mathematics: Discrete Methods
#     Terms:  Win
#     Units:  5
#     UG Reqs:  WAY-FR
#     Grading:  Letter (ABCD/NP)
#  - MATH 63CM
#     Title:  Modern Mathematics: Continuous Methods
#     Terms:  Spr
#     Units:  5
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter (ABCD/NP)
#  - MATH 63DM
#     Title:  Modern Mathematics: Discrete Methods
#     Terms:  Spr
#     Units:  5
#     UG Reqs:  WAY-FR
#     Grading:  Letter (ABCD/NP)
#  - MATH 83N
#     Title:  Proofs and Modern Mathematics
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 87Q
#     Title:  Mathematics of Knots, Braids, Links, and Tangles
#     Terms:  Win
#     Units:  3
#     UG Reqs:  WAY-FR
#     Grading:  Letter (ABCD/NP)
#  - MATH 104
#     Title:  Applied Matrix Theory
#     Terms:  Aut, Win, Spr, Sum
#     Units:  3
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 106
#     Title:  Functions of a Complex Variable
#     Terms:  Spr, Sum Win
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 107
#     Title:  Graph Theory
#     Terms:  Spr
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 108
#     Title:  Introduction to Combinatorics and Its Applications
#     Terms:  Win Spr
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 109
#     Title:  Applied Group Theory
#     Terms:  Aut Spr
#     Units:  3
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 110
#     Title:  Applied Number Theory and Field Theory
#     Terms:  Spr
#     Units:  3
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 113
#     Title:  Linear Algebra and Matrix Theory
#     Terms:  Aut, Win, Spr, Sum
#     Units:  3
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 114
#     Title:  Introduction to Scientific Computing (CME 108)
#     Terms:  Win, Sum
#     Units:  3
#     UG Reqs:  GER:DB-EngrAppSci, WAY-AQR, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 115
#     Title:  Functions of a Real Variable
#     Terms:  Aut, Spr, Sum
#     Units:  3
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 116
#     Title:  Complex Analysis
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 120
#     Title:  Groups and Rings
#     Terms:  Aut, Spr
#     Units:  3
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 121
#     Title:  Galois Theory
#     Terms:  Win
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 122
#     Title:  Modules and Group Representations
#     Terms:  Spr
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 131P
#     Title:  Partial Differential Equations
#     Terms:  Win
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 136
#     Title:  Stochastic Processes (STATS 219)
#     Terms:  Win
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 143
#     Title:  Differential Geometry
#     Terms:  Spr Win
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 146
#     Title:  Analysis on Manifolds
#     Terms:  Aut Spr
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 151
#     Title:  Introduction to Probability Theory
#     Terms:  Win
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 152
#     Title:  Elementary Theory of Numbers
#     Terms:  Win
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 158
#     Title:  Basic Probability and Stochastic Processes with Engineering Applications (CME 298)
#     Terms:  Spr
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 159
#     Title:  Discrete Probabilistic Methods
#     Terms:  Spr
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 171
#     Title:  Fundamental Concepts of Analysis
#     Terms:  Aut, Spr
#     Units:  3
#     UG Reqs:  GER:DB-Math, WAY-FR
#     Grading:  Letter or Credit/No Credit
#  - MATH 172
#     Title:  Lebesgue Integration and Fourier Analysis
#     Terms:  Spr
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 175
#     Title:  Elementary Functional Analysis
#     Terms:  Win
#     Units:  3
#     UG Reqs:  GER:DB-Math
#     Grading:  Letter or Credit/No Credit
#  - MATH 193
#     Title:  Polya Problem Solving Seminar
#     Terms:  Aut
#     Units:  1
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - MATH 197
#     Title:  Senior Honors Thesis
#     Terms:  Aut, Win, Spr, Sum
#     Units:  1-6
#     UG Reqs:  None
#     Grading:  Letter (ABCD/NP)
#  - MATH 199
#     Title:  Reading Topics
#     Terms:  Aut, Win, Spr, Sum
#     Units:  1-3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 205A
#     Title:  Real Analysis
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 205B
#     Title:  Real Analysis
#     Terms:  Win
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 210A
#     Title:  Modern Algebra I
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 210B
#     Title:  Modern Algebra II
#     Terms:  Win
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 210C
#     Title:  Lie Theory
#     Terms:  Spr
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 215A
#     Title:  Algebraic Topology
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 215B
#     Title:  Differential Topology
#     Terms:  Win
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 215C
#     Title:  Differential Geometry
#     Terms:  Spr
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 220
#     Title:  Partial Differential Equations of Applied Mathematics (CME 303)
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 226
#     Title:  Numerical Solution of Partial Differential Equations (CME 306)
#     Terms:  Spr
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 228
#     Title:  Stochastic Methods in Engineering (CME 308, MS&E 324)
#     Terms:  Spr
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 230A
#     Title:  Theory of Probability I (STATS 310A)
#     Terms:  Aut
#     Units:  2-4 3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 230B
#     Title:  Theory of Probability II (STATS 310B)
#     Terms:  Win
#     Units:  2-3 3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 230C
#     Title:  Theory of Probability III (STATS 310C)
#     Terms:  Spr
#     Units:  2-4
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 233A
#     Title:  Topics in Combinatorics
#     Terms:  Aut Win
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 236
#     Title:  Introduction to Stochastic Differential Equations
#     Terms:  Win
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 238
#     Title:  Mathematical Finance (STATS 250)
#     Terms:  Win
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 245A
#     Title:  Topics in Algebraic Geometry
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 245B
#     Title:  Topics in Algebraic Geometry
#     Terms:  Win
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 249A
#     Title:  Topics in number theory
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 256A
#     Title:  Partial Differential Equations
#     Terms:  Aut Spr
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 263A
#     Title:  Algebraic Combinatorics and Symmetric Functions
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 269
#     Title:  Topics in symplectic geometry
#     Terms:  Aut
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 272
#     Title:  Topics in Partial Differential Equations
#     Terms:  Spr Aut
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 282B
#     Title:  Homotopy Theory
#     Terms:  Win
#     Units:  3
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 298
#     Title:  Graduate Practical Training
#     Terms:  Aut, Win, Spr, Sum
#     Units:  1
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - MATH 355
#     Title:  Graduate Teaching Seminar
#     Terms:  Spr Win
#     Units:  1
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - MATH 360
#     Title:  Advanced Reading and Research
#     Terms:  Aut, Win, Spr, Sum
#     Units:  1-10
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit
#  - MATH 382
#     Title:  Qualifying Examination Seminar
#     Terms:  Win, Sum
#     Units:  1-3
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - MATH 802
#     Title:  TGR Dissertation
#     Terms:  Aut, Win, Spr, Sum
#     Units:  0
#     UG Reqs:  None
#     Grading:  TGR
