# %% [markdown]
# ## courses + new changes
# **july 14: don't use this version, use the reverted one in the same folder**
#
#
# - run entire notebook, the very last function is called `do_everything()`. to get, say, ECON course changes, just run `do_everything('ECON')`
#
# the following are hard-coded (will need to be updated in future years):
# - the base URL that everything begins from
# - typing 20182019 and 20192020 (eg next year change to 20192020 and 20202021)
#
# june 26, 2019

# %%
# autumn + winter + spring courses for 2018-2019
BASE_PAGE_URL = 'https://explorecourses.stanford.edu/search?q=LINGUIST&view=catalog&filter-term-Winter=on&filter-departmentcode-LINGUIST=on&filter-catalognumber-LINGUIST=on&academicYear=20182019&filter-term-Autumn=on&filter-term-Spring=on&page=0&filter-coursestatus-Active=on&collapse='

# %%
from bs4 import BeautifulSoup
from subprocess import check_output

# %%
def get_n_pages(pgs):
    lst = []
    for x in pgs:
        try:
            lst.append(int(x))
        except:
            pass
    return max(lst)

def get_search_results_on_page(url, year, ith):
    print('Parsing page', ith + 1)
    new_url = url.replace('page=0', 'page=' + str(ith))
    new_src = check_output([
        'wget',
        '-qO-',
        new_url
    ])
    parse = BeautifulSoup(new_src)
    return parse.body.find(
        'div',
        attrs={'id': 'searchResults'}
    )
    
def get_results_list(url, year='20182019'):
    src = check_output([
        'wget',
        '-qO-',
        url
    ])
    parse = BeautifulSoup(src)
    n_pages = get_n_pages(parse.body.find(
        'div',
        attrs={'id': 'pagination'}
    ).text.split())
    print('Need to parse', n_pages, 'pages')
    to_return = [get_search_results_on_page(url, year, ith) for ith in range(n_pages)]
    print('Done parsing!')
    return to_return

# %%
results_list = get_results_list(BASE_PAGE_URL)
# Out:
# Need to parse 7 pages
# Parsing page 1
# Parsing page 2
# Parsing page 3
# Parsing page 4
# Parsing page 5
# Parsing page 6
# Parsing page 7
# Done parsing!

# %%
legal_fields = {
    'Terms',
    'Units',
    'UG Reqs',
    'Grading'
}

def extract_data(fields):
    relevant_name_to_val = {}
    for item in fields:
        idx = item.find(':')
        field_name = item[:idx]
        if field_name in legal_fields:
            field_val = item[idx + 1:].strip()
            relevant_name_to_val[field_name] = field_val
    return relevant_name_to_val

def fetch_info(course, mp):
    code = course.find(
        'span',
        attrs={'class': 'courseNumber'}
    ).text.strip(':')
    mp[code] = {}
    name = course.find(
        'span',
        attrs={'class': 'courseTitle'}
    ).text
    mp[code]['Title'] = name
    
    attribs = course.find(
        'div',
        attrs={'class': 'courseAttributes'}
    ).text
    fields = [x.strip() for x in ' '.join(attribs.split()).split('|')]
    
    attribs_all = course.findAll(
        'div',
        attrs={'class': 'courseAttributes'}
    )
    
    instructors_set = None
    if len(attribs_all) > 1:
        fields = attribs_all[1].text.strip().split('\n')
        instructors_set = set([f.strip() for f in fields if 'PI' in f])
    
    extracted = extract_data(fields)    
    for field in legal_fields:
        if field in extracted:
            mp[code][field] = extracted[field]
        else:
            mp[code][field] = None
    
    mp[code]['Instructors'] = instructors_set
    
    desc = course.find(
        'div',
        attrs={'class': 'courseDescription'}
    ).text
    mp[code]['Desc.'] = desc

def parse_results_list(results_list):
    course_to_field_to_info_map_map = {}
    print('Parsing results html...')
    for results in results_list:
        all_courses = results.findAll(
            'div',
            attrs={'class': 'courseInfo'}
        )
        for course in all_courses:
            fetch_info(course, course_to_field_to_info_map_map)
    print('Done parsing!')
    return course_to_field_to_info_map_map

# %%
ling_20182019 = parse_results_list(results_list)
# Out:
# Parsing results html...
# Done parsing!

# %%
url_20192020 = BASE_PAGE_URL.replace('20182019', '20192020')
ling_20192020 = parse_results_list(get_results_list(url_20192020))
# Out:
# Need to parse 7 pages
# Parsing page 1
# Parsing page 2
# Parsing page 3
# Parsing page 4
# Parsing page 5
# Parsing page 6
# Parsing page 7
# Done parsing!
# Parsing results html...
# Done parsing!

# %%
import re
from termcolor import cprint

fields = [
    'Title',
    'Terms',
    'Units',
    'UG Reqs',
    'Grading'
]

# stackoverflow Mark Byers
def natural_sort(l): 
    convert = lambda text: int(text) if text.isdigit() else text.lower() 
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(l, key = alphanum_key)

def find_differences(A, B, a, b):
    print('Courses in ' + a + ' but not in ' + b + ':')
    for course in A:
        if course not in B:
            cprint(' - ' + course + '\n   - ' + A[course]['Title'], attrs=['bold'])
    print('\n')
    print('Courses in ' + b + ' but not in ' + a + ':')
    for course in B:
        if course not in A:
#             print(course, B[course]['Title'], B[course]['Terms'])
            cprint(' - ' + course + '\n   - ' + B[course]['Title'] + ' (' + str(B[course]['Terms']) + ')', attrs=['bold'])
    print('\nCourses Retained:')
    overlap = A.keys() & B.keys()
    for course in natural_sort(overlap):
        cprint(' - ' + course, attrs=['bold'])
        for f in fields:
            print('    ' + f + ': ', end=' ')
            if f not in A[course] or f not in B[course]:
                if f not in A[course]:
                    cprint('None', 'red', attrs=['bold'])
                else:
                    cprint(A[course], 'red', attrs=['bold'])
                if f not in B[course]:
                    cprint('None', 'green', attrs=['bold'])
                else:
                    cprint(B[course], 'green', attrs=['bold'])
            elif A[course][f] != B[course][f]:
                cprint(A[course][f], 'red', end=' ', attrs=['bold'])
                cprint(B[course][f], 'green', attrs=['bold'])
            else:
                print(A[course][f])

# %%
find_differences(ling_20182019, ling_20192020, 'Ling 18-19', 'Ling 19-20')
# Out:
# Courses in Ling 18-19 but not in Ling 19-20:
#  - LINGUIST 55N
#    - Language in the City
#  - LINGUIST 65
#    - African American Vernacular English (AFRICAAM 21, CSRE 21, LINGUIST 265)
#  - LINGUIST 83Q
#    - Translation
#  - LINGUIST 121A
#    - The Syntax of English
#  - LINGUIST 152
#    - Sociolinguistics and Pidgin Creole Studies (LINGUIST 252)
#  - LINGUIST 157
#    - Sociophonetics (LINGUIST 257)
#  - LINGUIST 160
#    - Introduction to Language Change
#  - LINGUIST 200
#    - Foundations of Linguistic Theory
#  - LINGUIST 207A
#    - Advanced Phonetics
#  - LINGUIST 211
#    - Metrics
#  - LINGUIST 225
#    - Seminar in Syntax: Distributed Morphology
#  - LINGUIST 236
#    - Seminar in Semantics: Causation
#  - LINGUIST 247
#    - Seminar in Psycholinguistics: Advanced Topics (PSYCH 227)
#  - LINGUIST 250
#    - Sociolinguistic Theory and Analysis
#  - LINGUIST 252
#    - Sociolinguistics and Pidgin Creole Studies (LINGUIST 152)
#  - LINGUIST 257
#    - Sociophonetics (LINGUIST 157)
#  - LINGUIST 265
#    - African American Vernacular English (AFRICAAM 21, CSRE 21, LINGUIST 65)
#  - LINGUIST 272
#    - Structure of Finnish
#  - LINGUIST 286
#    - Information Retrieval and Web Search (CS 276)
#
#
# Courses in Ling 19-20 but not in Ling 18-19:
#  - LINGUIST 54N
#    - Social Bias and Earwitness Memory (None)
#  - LINGUIST 121B
#    - Crosslinguistic Syntax (None)
#  - LINGUIST 132
#    - Lexical Semantic Typology (None)
#  - LINGUIST 167
#    - Languages of the World (Spr)
#  - LINGUIST 207L
#    - Phonetics Research Lab (None)
#  - LINGUIST 210B
#    - Advanced Phonology (None)
#  - LINGUIST 217
#    - Morphosyntax (Spr)
#  - LINGUIST 232B
#    - Seminar in Lexical Semantics:  Lexical semantic typology (Win)
#  - LINGUIST 247L
#    - Alps Research Lab (None)
#  - LINGUIST 257L
#    - Interactional Phonetics Research Lab (None)
#  - LINGUIST 258
#    - Analysis of Variation (None)
#  - LINGUIST 258A
#    - Variation and Social Meaning (None)
#  - LINGUIST 260A
#    - Historical Morphology and Phonology (None)
#  - LINGUIST 289L
#    - Computational Linguistics Research Labl (None)
#
# Courses Retained:
#  - LINGUIST 1
#     Title:  Introduction to Linguistics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 30N
#     Title:  Linguistic Meaning and the Law
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 35
#     Title:  Minds and Machines (PHIL 99, PSYCH 35, SYMSYS 1, SYMSYS 200)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 47N
#     Title:  Languages, Dialects, Speakers
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 90
#     Title:  Teaching Spoken English
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 105
#     Title:  Phonetics (LINGUIST 205A)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 110
#     Title:  Introduction to Phonology
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 130A
#     Title:  Introduction to Semantics and Pragmatics (LINGUIST 230A)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 130B
#     Title:  Introduction to Lexical Semantics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 145
#     Title:  Introduction to Psycholinguistics (LINGUIST 245A, PSYCH 140)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 150
#     Title:  Language and Society
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 156
#     Title:  Language and Gender (FEMGEN 156X)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 180
#     Title:  From Languages to Information (CS 124, LINGUIST 280)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 188
#     Title:  Natural Language Understanding (CS 224U, LINGUIST 288)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 191
#     Title:  Linguistics and the Teaching of English as a Second/Foreign Language (LINGUIST 291)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 195A
#     Title:  Undergraduate Research Workshop
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 196
#     Title:  Introduction to Research for Undergraduates
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 197A
#     Title:  Undergraduate Research Seminar
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 198
#     Title:  Honors Research
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 199
#     Title:  Independent Study
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 205A
#     Title:  Phonetics (LINGUIST 105)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 210A
#     Title:  Phonology
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 222A
#     Title:  Foundations of Syntactic Theory I
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 222B
#     Title:  Foundations of Syntactic Theory II
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 225S
#     Title:  Syntax and Morphology Research Seminar
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 230A
#     Title:  Introduction to Semantics and Pragmatics (LINGUIST 130A)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 230B
#     Title:  Semantics and Pragmatics I
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 230C
#     Title:  Semantics and Pragmatics II
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 232A
#     Title:  Lexical Semantics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 245A
#     Title:  Introduction to Psycholinguistics (LINGUIST 145, PSYCH 140)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 245B
#     Title:  Methods in Psycholinguistics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 255A
#     Title:  Seminar in Sociolinguistics: California Dialectology
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 255L
#     Title:  Seminar in Sociolinguistics: Multiracial Identity in Variation Studies
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 260B
#     Title:  Historical Morphosyntax
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 278
#     Title:  Programming for Linguists
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 280
#     Title:  From Languages to Information (CS 124, LINGUIST 180)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 284
#     Title:  Natural Language Processing with Deep Learning (CS 224N)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 288
#     Title:  Natural Language Understanding (CS 224U, LINGUIST 188)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 291
#     Title:  Linguistics and the Teaching of English as a Second/Foreign Language (LINGUIST 191)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 294
#     Title:  Linguistic Research Discussion Group
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 390
#     Title:  M.A. Project
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 391A
#     Title:  Curricular Practical Training
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 394
#     Title:  TA Training Workshop
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 395
#     Title:  Research Workshop
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 396
#     Title:  Research Projects in Linguistics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 397
#     Title:  Directed Reading
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 398
#     Title:  Directed Research
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - LINGUIST 399
#     Title:  Dissertation Research
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None

# %%
def do_everything(dept_code):
    url = BASE_PAGE_URL.replace('LINGUIST', dept_code)
    url_2 = url.replace('20182019', '20192020')
    a = parse_results_list(get_results_list(url))
    b = parse_results_list(get_results_list(url_2))
    find_differences(a, b, dept_code + ' 18-19', dept_code + ' 19-20')

# %%
do_everything('CS')
# Out:
# Need to parse 21 pages
# Parsing page 1
# Parsing page 2
# Parsing page 3
# Parsing page 4
# Parsing page 5
# Parsing page 6
# Parsing page 7
# Parsing page 8
# Parsing page 9
# Parsing page 10
# Parsing page 11
# Parsing page 12
# Parsing page 13
# Parsing page 14
# Parsing page 15
# Parsing page 16
# Parsing page 17
# Parsing page 18
# Parsing page 19
# Parsing page 20
# Parsing page 21
# Done parsing!
# Parsing results html...
# Done parsing!
# Need to parse 20 pages
# Parsing page 1
# Parsing page 2
# Parsing page 3
# Parsing page 4
# Parsing page 5
# Parsing page 6
# Parsing page 7
# Parsing page 8
# Parsing page 9
# Parsing page 10
# Parsing page 11
# Parsing page 12
# Parsing page 13
# Parsing page 14
# Parsing page 15
# Parsing page 16
# Parsing page 17
# Parsing page 18
# Parsing page 19
# Parsing page 20
# Done parsing!
# Parsing results html...
# Done parsing!
# Courses in CS 18-19 but not in CS 19-20:
#  - CS 11SI
#    - How to Make VR: Introduction to Virtual Reality Design and Development
#  - CS 17SI
#    - Frontiers in Reproductive Technology
#  - CS 18SI
#    - Geopolitical Ramifications of Technological Advances
#  - CS 19SI
#    - Evaluating Education Technology: Developing Frameworks to Make Sense of EdTech
#  - CS 21SI
#    - AI for Social Good
#  - CS 41
#    - Hap.py Code: The Python Programming Language
#  - CS 43
#    - Functional Programming Abstractions
#  - CS 47
#    - Cross-Platform Mobile Development
#  - CS 51
#    - CS + Social Good Studio: Designing Social Impact Projects
#  - CS 52
#    - CS + Social Good Studio
#  - CS 53
#    - DISCUSSIONS IN TECH FOR GOOD
#  - CS 101
#    - Introduction to Computing Principles
#  - CS 106AJ
#    - Programming Methodology in JavaScript
#  - CS 106AP
#    - Programming Methodology in Python
#  - CS 106S
#    - Coding for Social Good
#  - CS 146
#    - Introduction to Game Design and Development
#  - CS 229A
#    - Applied Machine Learning
#  - CS 229T
#    - Statistical Learning Theory (STATS 231)
#  - CS 247
#    - Human-Computer Interaction Design Studio
#  - CS 250
#    - Algebraic Error Correcting Codes (EE 387)
#  - CS 252
#    - Analysis of Boolean Functions
#  - CS 269G
#    - Almost Linear Time Graph Algorithms (MS&E 313)
#  - CS 269I
#    - Incentives in Computer Science
#  - CS 276
#    - Information Retrieval and Web Search (LINGUIST 286)
#  - CS 315B
#    - Parallel Computing Research Project
#  - CS 316
#    - Advanced Multi-Core Systems
#  - CS 332
#    - Advanced Survey of Reinforcement Learning
#  - CS 333
#    - Safe and Interactive Robotics
#  - CS 349D
#    - Cloud Computing Technology
#  - CS 349E
#    - Understanding Datacenter Software Dynamics
#  - CS 358
#    - Topics in Programming Language Theory
#  - CS 369L
#    - Algorithmic Perspective on Machine Learning
#  - CS 369M
#    - Metric Embeddings and Algorithmic Applications
#  - CS 376
#    - Human-Computer Interaction Research
#  - CS 377E
#    - Designing Solutions to Global Grand Challenges
#  - CS 390P
#    - Part-time Curricular Practical Training
#  - CS 390Q
#    - Part-Time Curricular Practical Training
#  - CS 390U
#    - Part-Time Curricular Practical Training
#  - CS 390V
#    - Part-time Curricular Practical Training
#  - CS 390W
#    - Part-time Curricular Practical Training
#  - CS 428
#    - Computation and Cognition: The Probabilistic Approach (PSYCH 204)
#  - CS 431
#    - High-level Vision: From Neurons to Deep Neural Networks (PSYCH 250)
#  - CS 522
#    - Seminar in Artificial Intelligence in Healthcare
#  - CS 544
#    - INTERACTIVE MEDIA AND GAMES (BIOE 196, BIOPHYS 196)
#  - CS 549
#    - Human-Computer Interaction in the Real World
#  - CS 571
#    - Surgical Robotics Seminar (ME 571)
#
#
# Courses in CS 19-20 but not in CS 18-19:
#  - CS 28
#    - Artificial Intelligence, Entrepreneurship and Society in the 21st Century and Beyond (None)
#  - CS 57N
#    - Randomness: Computational and Philosophical Approaches (PHIL 3N) (None)
#  - CS 106AX
#    - Programming Methodologies in JavaScript and Python (Accelerated) (None)
#  - CS 129
#    - Applied Machine Learning (None)
#  - CS 152
#    - Trust and Safety Engineering (None)
#  - CS 182
#    - Ethics, Public Policy, and Technological Change (COMM 180, ETHICSOC 182, PHIL 82, POLISCI 182, PUBLPOL 182) (Win)
#  - CS 182W
#    - Ethics, Public Policy, and Technological Change (WIM) (Win)
#  - CS 193X
#    - Web Programming Fundamentals (Spr)
#  - CS 197
#    - Computer Science Research (None)
#  - CS 197A
#    - Computer Science Research Seminar (None)
#  - CS 231C
#    - Computer Vision and Image Analysis of Art (None)
#  - CS 233
#    - Geometric and Topological Data Analysis (CME 251) (Spr)
#  - CS 237A
#    - Principles of Robotic Autonomy I (AA 174A, AA 274A, EE 260A) (None)
#  - CS 237B
#    - Principles of Robot Autonomy II (AA 174B, AA 274B, EE 260B) (Win)
#  - CS 239
#    - Advanced Topics in Sequential Decision Making (AA 229) (Win)
#  - CS 247A
#    - Design for Artificial Intelligence (None)
#  - CS 247G
#    - Introduction to Game Design (None)
#  - CS 247I
#    - Design for Understanding (None)
#  - CS 247S
#    - Service Design (None)
#  - CS 253
#    - Building for Digital Health (MED 253) (None)
#  - CS 254B
#    - Computational Complexity II (Spr)
#  - CS 259Q
#    - Quantum Computing (Win)
#  - CS 330
#    - Deep Multi-task and Meta Learning (None)
#  - CS 336
#    - Robot Perception and Decision-Making: Optimal and Learning-based Approaches (None)
#  - CS 347
#    - Human-Computer Interaction Research (None)
#  - CS 348E
#    - Character Animation: Modeling, Simulation, and Control of Human Motion (Spr)
#  - CS 353
#    - The Practice of Theory Research (None)
#  - CS 358A
#    - Programming Language Foundations (Win)
#  - CS 368
#    - Algorithmic Techniques for Big Data (Spr)
#  - CS 373
#    - Statistical and Machine Learning Methods for Genomics (BIO 268, BIOMEDIN 245, GENE 245, STATS 345) (Win)
#  - CS 377T
#    - Topics in Human-Computer Interaction: Teaching Studio Classes (None)
#  - CS 384
#    - Seminar on Ethical and Social Issues in Natural Language Processing (None)
#  - CS 398
#    - Computational Education (None)
#
# Courses Retained:
#  - CS 1C
#     Title:  Introduction to Computing at Stanford (VPTL 1)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 1U
#     Title:  Practical Unix
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 7
#     Title:  Personal Finance for Engineers
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 22A
#     Title:  The Social & Economic Impact of Artificial Intelligence (INTLPOL 200)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 45N
#     Title:  Computers and Photography: From Capture to Sharing
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 49N
#     Title:  Using Bits to Control Atoms
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 56N
#     Title:  Great Discoveries and Inventions in Computing
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 58
#     Title:  You Say You Want a Revolution (Blockchain Edition)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 80Q
#     Title:  Race and Gender in Silicon Valley (AFRICAAM 80Q)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 83
#     Title:  Playback Theater For Research Playback Theater
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 93
#     Title:  Teaching AI
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 100A
#     Title:  Problem-solving Lab for CS106A
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 100B
#     Title:  Problem-solving Lab for CS106B
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 102
#     Title:  Big Data - Tools and Techniques Working with Data - Tools and Techniques
#     Terms:  None Spr
#     Units:  None 3-4
#     UG Reqs:  None WAY-AQR
#     Grading:  None Letter or Credit/No Credit
#  - CS 103
#     Title:  Mathematical Foundations of Computing
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 103A
#     Title:  Mathematical Problem-solving Strategies
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 105
#     Title:  Introduction to Computers
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 106A
#     Title:  Programming Methodology (ENGR 70A) Programming Methodology
#     Terms:  None Aut, Win, Spr, Sum
#     Units:  None 3-5
#     UG Reqs:  None GER:DB-EngrAppSci, WAY-FR
#     Grading:  None Letter or Credit/No Credit
#  - CS 106B
#     Title:  Programming Abstractions (ENGR 70B) Programming Abstractions
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 106E
#     Title:  Practical Exploration of Computing Exploration of Computing
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 106L
#     Title:  Standard C++ Programming Laboratory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 106X
#     Title:  Programming Abstractions (Accelerated) (ENGR 70X) Programming Abstractions (Accelerated)
#     Terms:  None Aut, Win
#     Units:  None 3-5
#     UG Reqs:  None GER:DB-EngrAppSci, WAY-FR
#     Grading:  None Letter or Credit/No Credit
#  - CS 107
#     Title:  Computer Organization and Systems
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 107A
#     Title:  Problem-solving Lab for CS107
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 107E
#     Title:  Computer Systems from the Ground Up
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 108
#     Title:  Object-Oriented Systems Design
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 109
#     Title:  Introduction to Probability for Computer Scientists
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 110
#     Title:  Principles of Computer Systems
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 124
#     Title:  From Languages to Information (LINGUIST 180, LINGUIST 280)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 131
#     Title:  Computer Vision: Foundations and Applications
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 140
#     Title:  Operating Systems and Systems Programming
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 140E
#     Title:  Operating systems design and implementation
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 142
#     Title:  Web Applications
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 143
#     Title:  Compilers
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 144
#     Title:  Introduction to Computer Networking
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 145
#     Title:  Data Management and Data Systems
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 147
#     Title:  Introduction to Human-Computer Interaction Design
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 148
#     Title:  Introduction to Computer Graphics and Imaging
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 149
#     Title:  Parallel Computing
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 151
#     Title:  Logic Programming
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 154
#     Title:  Introduction to Automata and Complexity Theory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 155
#     Title:  Computer and Network Security
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 157
#     Title:  Computational Logic
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 161
#     Title:  Design and Analysis of Algorithms
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 166
#     Title:  Data Structures
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 168
#     Title:  The Modern Algorithmic Toolbox
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 170
#     Title:  Stanford Laptop Orchestra: Composition, Coding, and Performance (MUSIC 128)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 181
#     Title:  Computers, Ethics, and Public Policy (COMM 181, ETHICSOC 181X, PHIL 75C, POLISCI 181, PUBLPOL 181) Computers, Ethics, and Public Policy
#     Terms:  None Spr
#     Units:  None 4
#     UG Reqs:  None GER:EC-EthicReas, WAY-ER
#     Grading:  None Letter or Credit/No Credit
#  - CS 181W
#     Title:  Computers, Ethics, and Public Policy (WIM)
#     Terms:  None Spr
#     Units:  None 4
#     UG Reqs:  None GER:EC-EthicReas, WAY-ER
#     Grading:  None Letter (ABCD/NP)
#  - CS 183E
#     Title:  Effective Leadership in High-Tech
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 190
#     Title:  Software Design Studio
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 191
#     Title:  Senior Project
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 191W
#     Title:  Writing Intensive Senior Project (WIM)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 192
#     Title:  Programming Service Project
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 193A
#     Title:  Android Programming
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 193P
#     Title:  iOS Application Development
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 193Q
#     Title:  Introduction to Python Programming
#     Terms:  None Spr
#     Units:  None 1
#     UG Reqs:  None
#     Grading:  None Satisfactory/No Credit
#  - CS 194
#     Title:  Software Project
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 194H
#     Title:  User Interface Design Project
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 194W
#     Title:  Software Project (WIM)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 195
#     Title:  Supervised Undergraduate Research
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 196
#     Title:  Computer Consulting (VPTL 196)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 198
#     Title:  Teaching Computer Science
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 198B
#     Title:  Additional Topics in Teaching Computer Science
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 199
#     Title:  Independent Work
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 199P
#     Title:  Independent Work
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 202
#     Title:  Law for Computer Science Professionals
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 204
#     Title:  Legal Informatics
#     Terms:  None Spr
#     Units:  None 2-3
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - CS 205L
#     Title:  Continuous Mathematical Methods with an Emphasis on Machine Learning
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 206
#     Title:  Exploring Computational Journalism (COMM 281)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 208E
#     Title:  Great Ideas in Computer Science
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 209
#     Title:  Law, Bias, & Algorithms (CSRE 230, MS&E 330, SOC 279)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 210A
#     Title:  Software Project Experience with Corporate Partners
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 210B
#     Title:  Software Project Experience with Corporate Partners
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 217
#     Title:  Hardware Accelerators for Machine Learning
#     Terms:  None Win
#     Units:  None 3-4
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - CS 221
#     Title:  Artificial Intelligence: Principles and Techniques
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 223A
#     Title:  Introduction to Robotics (ME 320)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 224N
#     Title:  Natural Language Processing with Deep Learning (LINGUIST 284)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 224U
#     Title:  Natural Language Understanding (LINGUIST 188, LINGUIST 288)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 224W
#     Title:  Analysis of Networks Machine Learning with Graphs
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 225A
#     Title:  Experimental Robotics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 227B
#     Title:  General Game Playing
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 228
#     Title:  Probabilistic Graphical Models: Principles and Techniques
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 229
#     Title:  Machine Learning (STATS 229)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 230
#     Title:  Deep Learning
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 231N
#     Title:  Convolutional Neural Networks for Visual Recognition
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 232
#     Title:  Digital Image Processing (EE 368)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 234
#     Title:  Reinforcement Learning
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 236
#     Title:  Deep Generative Models
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 238
#     Title:  Decision Making under Uncertainty (AA 228)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 240
#     Title:  Advanced Topics in Operating Systems
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 242
#     Title:  Programming Languages
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 243
#     Title:  Program Analysis and Optimizations
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 244
#     Title:  Advanced Topics in Networking
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 245
#     Title:  Principles of Data-Intensive Systems
#     Terms:  None Win
#     Units:  None 3
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - CS 246
#     Title:  Mining Massive Data Sets
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 246H
#     Title:  Mining Massive Data Sets Hadoop Lab
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 248
#     Title:  Interactive Computer Graphics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 251
#     Title:  Cryptocurrencies and blockchain technologies
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 254
#     Title:  Computational Complexity
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 255
#     Title:  Introduction to Cryptography
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 261
#     Title:  Optimization and Algorithmic Paradigms
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 265
#     Title:  Randomized Algorithms and Probabilistic Analysis (CME 309)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 269O
#     Title:  Introduction to Optimization Theory (MS&E 213)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 269Q
#     Title:  Elements of Quantum Computer Programming
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 270
#     Title:  Modeling Biomedical Systems: Ontology, Terminology, Problem Solving (BIOMEDIN 210)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 272
#     Title:  Introduction to Biomedical Informatics Research Methodology (BIOE 212, BIOMEDIN 212, GENE 212)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 273A
#     Title:  The Human Genome Source Code (BIOMEDIN 273A, DBIO 273A)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 273B
#     Title:  Deep Learning in Genomics and Biomedicine (BIODS 237, BIOMEDIN 273B, GENE 236)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 274
#     Title:  Representations and Algorithms for Computational Molecular Biology (BIOE 214, BIOMEDIN 214, GENE 214)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 275
#     Title:  Translational Bioinformatics (BIOE 217, BIOMEDIN 217, GENE 217)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 275A
#     Title:  Symbolic Musical Information (MUSIC 253)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 275B
#     Title:  Music Query, Analysis, and Style Simulation (MUSIC 254)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 278
#     Title:  Social Computing
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 279
#     Title:  Computational Biology: Structure and Organization of Biomolecules and Cells (BIOE 279, BIOMEDIN 279, BIOPHYS 279, CME 279)
#     Terms:  not given this year None
#     Units:  3 None
#     UG Reqs:  None
#     Grading:  Letter or Credit/No Credit None
#  - CS 294S
#     Title:  Research Project in Software Systems and Security
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 294W
#     Title:  Writing Intensive Research Project in Computer Science
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 298
#     Title:  Seminar on Teaching Introductory Computer Science (EDUC 298)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 300
#     Title:  Departmental Lecture Series
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 309A
#     Title:  Cloud Computing Seminar
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 325B
#     Title:  Data for Sustainable Development (EARTHSYS 162, EARTHSYS 262)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 326
#     Title:  Topics in Advanced Robotic Manipulation
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 327A
#     Title:  Advanced Robotic Manipulation
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 334A
#     Title:  Convex Optimization I (CME 364A, EE 364A)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 337
#     Title:  AI-Assisted Care (MED 277)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 341
#     Title:  Project in Mining Massive Data Sets
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 344
#     Title:  Topics in Computer Networks
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 348B
#     Title:  Computer Graphics: Image Synthesis Techniques
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 348C
#     Title:  Computer Graphics: Animation and Simulation
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 348K
#     Title:  Visual Computing Systems
#     Terms:  None Spr
#     Units:  None 3-4
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - CS 349F
#     Title:  Technology for Financial Systems
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 350
#     Title:  Secure Compilation
#     Terms:  None Spr
#     Units:  None 3
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - CS 354
#     Title:  Topics in Intractability: Unfulfilled Algorithmic Fantasies
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 355
#     Title:  Advanced Topics in Cryptography
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 356
#     Title:  Topics in Computer and Network Security
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 361
#     Title:  Engineering Design Optimization (AA 222)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 375
#     Title:  Large-Scale Neural Network Modeling for Neuroscience (PSYCH 249)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 377G
#     Title:  Designing Serious Games
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 377N
#     Title:  Introduction to the Design of Smart Products (ME 216M)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 377Q
#     Title:  Designing for Accessibility
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 377U
#     Title:  Understanding Users
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 379C
#     Title:  Computational Models of the Neocortex
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 390A
#     Title:  Curricular Practical Training
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 390B
#     Title:  Curricular Practical Training
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 390C
#     Title:  Curricular Practical Training
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 390D
#     Title:  Part-time Curricular Practical Training
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 393
#     Title:  Computer Laboratory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 395
#     Title:  Independent Database Project
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 399
#     Title:  Independent Project
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 399P
#     Title:  Independent Project
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 402
#     Title:  Beyond Bits and Atoms: Designing Technological Tools (EDUC 236)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 402L
#     Title:  Beyond Bits and Atoms - Lab (EDUC 211)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 421
#     Title:  Designing AI to Cultivate Human Well-Being
#     Terms:  None Win
#     Units:  None 2
#     UG Reqs:  None
#     Grading:  None Satisfactory/No Credit
#  - CS 448B
#     Title:  Data Visualization
#     Terms:  None Win
#     Units:  None 4
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - CS 448I
#     Title:  Computational Imaging and Display (EE 367)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 448M
#     Title:  Making Making Machines for Makers
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 448V
#     Title:  Topics in Computer Graphics: Computational Video Manipulation
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 476A
#     Title:  Music, Computing, Design I: The Art of Design (MUSIC 256A)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 499
#     Title:  Advanced Reading and Research
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 499P
#     Title:  Advanced Reading and Research
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 547
#     Title:  Human-Computer Interaction Seminar
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 581
#     Title:  Media Innovation
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 801
#     Title:  TGR Project
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - CS 802
#     Title:  TGR Dissertation
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None

# %%
do_everything('MATH')
# Out:
# Need to parse 9 pages
# Parsing page 1
# Parsing page 2
# Parsing page 3
# Parsing page 4
# Parsing page 5
# Parsing page 6
# Parsing page 7
# Parsing page 8
# Parsing page 9
# Done parsing!
# Parsing results html...
# Done parsing!
# Need to parse 9 pages
# Parsing page 1
# Parsing page 2
# Parsing page 3
# Parsing page 4
# Parsing page 5
# Parsing page 6
# Parsing page 7
# Parsing page 8
# Parsing page 9
# Done parsing!
# Parsing results html...
# Done parsing!
# Courses in MATH 18-19 but not in MATH 19-20:
#  - MATH 114
#    - Introduction to Scientific Computing (CME 108)
#  - MATH 137
#    - Mathematical Methods of Classical Mechanics
#  - MATH 145
#    - Algebraic Geometry
#  - MATH 148
#    - Algebraic Topology
#  - MATH 154
#    - Algebraic Number Theory
#  - MATH 161
#    - Set Theory
#  - MATH 234
#    - Large Deviations Theory (STATS 374)
#  - MATH 235A
#    - Topics in combinatorics
#  - MATH 237A
#    - Topics in Financial Math: Market microstructure and trading algorithms
#  - MATH 249A
#    - Topics in number theory
#  - MATH 256B
#    - Partial Differential Equations
#  - MATH 257C
#    - Symplectic Geometry and Topology
#  - MATH 263A
#    - Algebraic Combinatorics and Symmetric Functions
#  - MATH 269
#    - Topics in symplectic geometry
#  - MATH 273
#    - Topics in Mathematical Physics (STATS 359)
#  - MATH 275
#    - Topics in Applied Mathematics: A World of Flows
#  - MATH 305
#    - Applied mathematics through toys and magic
#
#
# Courses in MATH 19-20 but not in MATH 18-19:
#  - MATH 142
#    - Hyperbolic Geometry (Spr)
#  - MATH 147
#    - Differential Topology (None)
#  - MATH 155
#    - Analytic Number Theory (None)
#  - MATH 173
#    - Theory of Partial Differential Equations (None)
#  - MATH 177
#    - Geometric Methods in the Theory of Ordinary Differential Equations (None)
#  - MATH 205C
#    - Real Analysis (None)
#  - MATH 216A
#    - Introduction to Algebraic Geometry (None)
#  - MATH 216B
#    - Introduction to Algebraic Geometry (Win)
#  - MATH 233B
#    - Topics in Combinatorics: Polyhedral Techniques in Optimization (Win)
#  - MATH 233C
#    - Topics in Combinatorics (Spr)
#  - MATH 235B
#    - Modern Markov Chain Theory (None)
#  - MATH 249B
#    - Topics in Number Theory (None)
#  - MATH 249C
#    - Topics in Number Theory (None)
#  - MATH 257A
#    - Symplectic Geometry and Topology (None)
#  - MATH 257B
#    - Symplectic Geometry and Topology (Win)
#  - MATH 258
#    - Topics in Geometric Analysis (Win)
#  - MATH 283A
#    - Topics in Topology (Spr)
#  - MATH 286
#    - Topics in Differential Geometry (None)
#  - MATH 391
#    - Seminar on Logic & Formal Philosophy (PHIL 391) (None)
#
# Courses Retained:
#  - MATH 19
#     Title:  Calculus
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 20
#     Title:  Calculus
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 21
#     Title:  Calculus
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 21A
#     Title:  Calculus, ACE
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 51
#     Title:  Linear Algebra, Multivariable Calculus, and Modern Applications
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 51A
#     Title:  Linear Algebra, Multivariable Calculus, and Modern Applications, ACE
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 52
#     Title:  Integral Calculus of Several Variables
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 53
#     Title:  Ordinary Differential Equations with Linear Algebra
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 61CM
#     Title:  Modern Mathematics: Continuous Methods
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 61DM
#     Title:  Modern Mathematics: Discrete Methods
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 62CM
#     Title:  Modern Mathematics: Continuous Methods
#     Terms:  None Spr
#     Units:  None 5
#     UG Reqs:  None GER:DB-Math, WAY-FR
#     Grading:  None Letter (ABCD/NP)
#  - MATH 62DM
#     Title:  Modern Mathematics: Discrete Methods
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 63CM
#     Title:  Modern Mathematics: Continuous Methods
#     Terms:  None Win
#     Units:  None 5
#     UG Reqs:  None GER:DB-Math, WAY-FR
#     Grading:  None Letter (ABCD/NP)
#  - MATH 63DM
#     Title:  Modern Mathematics: Discrete Methods
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 83N
#     Title:  Proofs and Modern Mathematics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 87Q
#     Title:  Mathematics of Knots, Braids, Links, and Tangles
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 104
#     Title:  Applied Matrix Theory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 106
#     Title:  Functions of a Complex Variable
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 107
#     Title:  Graph Theory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 108
#     Title:  Introduction to Combinatorics and Its Applications
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 109
#     Title:  Applied Group Theory
#     Terms:  None Spr
#     Units:  None 3
#     UG Reqs:  None GER:DB-Math, WAY-FR
#     Grading:  None Letter or Credit/No Credit
#  - MATH 110
#     Title:  Applied Number Theory and Field Theory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 113
#     Title:  Linear Algebra and Matrix Theory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 115
#     Title:  Functions of a Real Variable
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 116
#     Title:  Complex Analysis
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 120
#     Title:  Groups and Rings
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 121
#     Title:  Galois Theory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 122
#     Title:  Modules and Group Representations
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 131P
#     Title:  Partial Differential Equations
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 136
#     Title:  Stochastic Processes (STATS 219)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 143
#     Title:  Differential Geometry
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 146
#     Title:  Analysis on Manifolds
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 151
#     Title:  Introduction to Probability Theory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 152
#     Title:  Elementary Theory of Numbers
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 158
#     Title:  Basic Probability and Stochastic Processes with Engineering Applications (CME 298)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 159
#     Title:  Discrete Probabilistic Methods
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 171
#     Title:  Fundamental Concepts of Analysis
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 172
#     Title:  Lebesgue Integration and Fourier Analysis
#     Terms:  None Spr
#     Units:  None 3
#     UG Reqs:  None GER:DB-Math
#     Grading:  None Letter or Credit/No Credit
#  - MATH 175
#     Title:  Elementary Functional Analysis
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 193
#     Title:  Polya Problem Solving Seminar
#     Terms:  None Aut
#     Units:  None 1
#     UG Reqs:  None
#     Grading:  None Satisfactory/No Credit
#  - MATH 197
#     Title:  Senior Honors Thesis
#     Terms:  None Aut, Win, Spr, Sum
#     Units:  None 1-6
#     UG Reqs:  None
#     Grading:  None Letter (ABCD/NP)
#  - MATH 199
#     Title:  Reading Topics
#     Terms:  None Aut, Win, Spr, Sum
#     Units:  None 1-3
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - MATH 205A
#     Title:  Real Analysis
#     Terms:  None Aut
#     Units:  None 3
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - MATH 205B
#     Title:  Real Analysis
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 210A
#     Title:  Modern Algebra I
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 210B
#     Title:  Modern Algebra II
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 210C
#     Title:  Lie Theory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 215A
#     Title:  Algebraic Topology
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 215B
#     Title:  Differential Topology
#     Terms:  None Win
#     Units:  None 3
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - MATH 215C
#     Title:  Differential Geometry
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 220
#     Title:  Partial Differential Equations of Applied Mathematics (CME 303)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 226
#     Title:  Numerical Solution of Partial Differential Equations (CME 306)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 228
#     Title:  Stochastic Methods in Engineering (CME 308, MS&E 324)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 230A
#     Title:  Theory of Probability I (STATS 310A)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 230B
#     Title:  Theory of Probability II (STATS 310B)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 230C
#     Title:  Theory of Probability III (STATS 310C)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 233A
#     Title:  Topics in Combinatorics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 236
#     Title:  Introduction to Stochastic Differential Equations
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 238
#     Title:  Mathematical Finance (STATS 250)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 245A
#     Title:  Topics in Algebraic Geometry
#     Terms:  None Aut
#     Units:  None 3
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - MATH 245B
#     Title:  Topics in Algebraic Geometry
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 256A
#     Title:  Partial Differential Equations
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 263C
#     Title:  Topics in Representation Theory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 272
#     Title:  Topics in Partial Differential Equations
#     Terms:  None Aut
#     Units:  None 3
#     UG Reqs:  None
#     Grading:  None Letter or Credit/No Credit
#  - MATH 282B
#     Title:  Homotopy Theory
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 298
#     Title:  Graduate Practical Training
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 355
#     Title:  Graduate Teaching Seminar
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 360
#     Title:  Advanced Reading and Research
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 382
#     Title:  Qualifying Examination Seminar
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - MATH 802
#     Title:  TGR Dissertation
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None

# %%
do_everything('PWR')
# Out:
# Need to parse 12 pages
# Parsing page 1
# Parsing page 2
# Parsing page 3
# Parsing page 4
# Parsing page 5
# Parsing page 6
# Parsing page 7
# Parsing page 8
# Parsing page 9
# Parsing page 10
# Parsing page 11
# Parsing page 12
# Done parsing!
# Parsing results html...
# Done parsing!
# Need to parse 14 pages
# Parsing page 1
# Parsing page 2
# Parsing page 3
# Parsing page 4
# Parsing page 5
# Parsing page 6
# Parsing page 7
# Parsing page 8
# Parsing page 9
# Parsing page 10
# Parsing page 11
# Parsing page 12
# Parsing page 13
# Parsing page 14
# Done parsing!
# Parsing results html...
# Done parsing!
# Courses in PWR 18-19 but not in PWR 19-20:
#  - PWR 1IF
#    - Writing & Rhetoric 1: The Rhetoric of Language and Social Identity in America
#  - PWR 1RL
#    - Writing & Rhetoric 1: The Rhetoric of Happiness
#  - PWR 2BRB
#    - Writing & Rhetoric 2: Eurekas and Epiphanies: The Rhetoric of Inspiration
#  - PWR 91EE
#    - Intermediate Writing: Saving Lives with Picture Books
#  - PWR 91KD
#    - Intermediate Writing: Scripting Entertainments (for a Better YouTube)
#  - PWR 91TB
#    - Intermediate Writing: Being ____ at Stanford
#  - PWR 194CW
#    - Brave New Worlds: An Introduction to (De)colonial Rhetorics
#
#
# Courses in PWR 19-20 but not in PWR 18-19:
#  - PWR 1AB
#    - Writing & Rhetoric 1: Podcasts to Broadcasts: The Rhetoric of Radio (Aut)
#  - PWR 1HF
#    - Writing and Rhetoric 1: Rhetoric of Fulton (Aut, Win, Spr)
#  - PWR 1IY
#    - Writing & Rhetoric 1: Rhetorics of Travel and Tourism (None)
#  - PWR 1JJA
#    - Writing and Rhetoric 1: Rhetoric of Johnson A (None)
#  - PWR 1KR
#    - Writing & Rhetoric 1: Trust, Rhetoric, and Writing (Aut, Win, Spr)
#  - PWR 1LS
#    - Writing & Rhetoric 1: Unequal by Design? The Rhetoric of Race, Class, and Education (None)
#  - PWR 1MA
#    - Writing and Rhetoric 1: Rhetoric of Anwar (Aut, Win, Spr)
#  - PWR 1NF
#    - Writing & Rhetoric 1: Language 2.0: Investigating the Rhetoric of Digital Language (None)
#  - PWR 1RLA
#    - Writing & Rhetoric 1: The Rhetoric of Raechel Lee (None)
#  - PWR 1SNA
#    - Writing and Rhetoric 1: Rhetoric of Hervey A (None)
#  - PWR 1TD
#    - Writing & Rhetoric 1: Anatomy of a Discipline: Rhetorics of Health, Illness, and Medicine (None)
#  - PWR 1TSD
#    - Writing and Rhetoric 1: Rhetoric of Schaeffer D (None)
#  - PWR 2AF
#    - Writing and Rhetoric 2: Rhetoric of Fyre (None)
#  - PWR 2AY
#    - Writing & Rhetoric 2: Rhetoric of A Hammann (None)
#  - PWR 2CK
#    - Writing & Rhetoric 2: Speaking Out: Claiming Citizenship, Demanding Rights (None)
#  - PWR 2CW
#    - Writing & Rhetoric 2: Rhetorical Games: Sport (for) Development Policy in the 21st Century (None)
#  - PWR 2DH
#    - Writing & Rhetoric 2:  I ____ Therefore I Am? The Rhetoric of 21st Century Identity (None)
#  - PWR 2EI
#    - Writing and Rhetoric 2: Rhetoric of Pei (None)
#  - PWR 2GO
#    - Writing and Rhetoric 2: Rhetoric of Otalvaro (None)
#  - PWR 2HK
#    - Writing and Rhetoric 2: Rhetoric of Kantor (None)
#  - PWR 2JPB
#    - Writing and Rhetoric 2: Curated Reality: How Media Shape What We Know (Aut, Win)
#  - PWR 2KDC
#    - Writing and Rhetoric 2: Rhetoric of DiPirro C (None)
#  - PWR 2LF
#    - Writing & Rhetoric 2: The Rhetoric of Hacking (Win)
#  - PWR 2LL
#    - Writing & Rhetoric 2: Rhetoric of L Lamboy (None)
#  - PWR 2MFC
#    - Writing & Rhetoric 2: March for Science? Social Justice and the Rhetoric of Science (Spr)
#  - PWR 2RY
#    - Writing and Rhetoric 2: Rhetoric of Yang (None)
#  - PWR 2SP
#    - Writing & Rhetoric 2:  Literacy: Reading, Writing, Power (None)
#  - PWR 2TBA
#    - Writing and Rhetoric 2: Rhetoric of Brown A (None)
#  - PWR 2YZ
#    - Writing and Rhetoric 2: Rhetoric of Zhang (None)
#  - PWR 6LSP
#    - PWR 6 Leland Scholars Program: Exploring Research, Writing and Argument at Stanford (Aut)
#  - PWR 91CW
#    - Intermediate Writing: Seeing is Believing (None)
#  - PWR 91KSA
#    - Intermediate Writing: Storytelling and Science (None)
#  - PWR 194AV
#    - ADV PWR: AV (None)
#  - PWR 194NCR
#    - Topics in Writing & Rhetoric: Introduction to Cultural Rhetorics (Win)
#
# Courses Retained:
#  - PWR 1ABA
#     Title:  Writing & Rhetoric 1: The Rhetoric of Space Exploration
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1AF
#     Title:  Writing & Rhetoric 1: Schooling in the American Mind: Rhetorics of Teaching and Learning
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1AH
#     Title:  Writing & Rhetoric 1:  The Rhetoric of American Multicultural Experience
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1AL
#     Title:  Writing & Rhetoric 1: Schooling in the American Mind: Rhetorics of Teaching and Learning
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1AN
#     Title:  Writing & Rhetoric 1: The Rhetoric of Identity Cultivated Through a Hip-Hop World
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1AY
#     Title:  Writing & Rhetoric 1: Rhetoric of American Memory: Writing and Revising the Legacy of the Civil War
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1BRB
#     Title:  Writing & Rhetoric 1: In Another's Shoes: The Rhetoric of Empathy
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1CA
#     Title:  Writing & Rhetoric 1: The Rhetoric of Gaming
#     Terms:  Aut
#     Units:  4
#     UG Reqs:  Writing 1
#     Grading:  Letter (ABCD/NP)
#  - PWR 1CK
#     Title:  Writing & Rhetoric 1:  Investigating the News: Journalism, Technology & the Future
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1CLB
#     Title:  Writing & Rhetoric 1: Writing on Campus Life
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1DH
#     Title:  Writing & Rhetoric 1:  The Virtue of Vice and the Vice of Virtue: The Rhetoric of Criminality
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1EE
#     Title:  Writing & Rhetoric 1:  Prowling Toward Certainty: Exploration as Argument
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1EI
#     Title:  Writing & Rhetoric 1: Another Scene: Writing About Why Movies Matter
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1EP
#     Title:  Writing & Rhetoric 1: The Rhetoric of Global Development and Social Change
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1GMD
#     Title:  Writing & Rhetoric 1: Violent Innocents: Writing Our Way Out of American History
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1GO
#     Title:  Writing & Rhetoric 1: Art, Writing, and Performance: The Rhetoric of Visual Analysis
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1HK
#     Title:  Writing & Rhetoric 1: Food Values: The Rhetoric of What and How We Eat
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1IYA
#     Title:  Writing & Rhetoric 1: The Art and Science of Gender and its Bending
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1JJ
#     Title:  Writing & Rhetoric 1: The Rhetoric of Language and Thought
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1JPA
#     Title:  Writing & Rhetoric 1:  The Rhetoric of Liberal Arts Education
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1JSA
#     Title:  Writing & Rhetoric 1: The Rhetoric of Plants
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1KD
#     Title:  Writing & Rhetoric 1:  The Feature Article:  Writing and Change
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1KSB
#     Title:  Writing & Rhetoric 1: Health Matters: Health Innovation and Communication
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1KTA
#     Title:  Writing & Rhetoric 1: "That's Entertainment!" The Rhetoric of Hollywood's Inequities
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1LF
#     Title:  Writing & Rhetoric 1: The New Normal: The Rhetoric of Disability
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1LL
#     Title:  Writing & Rhetoric 1: The Rhetoric of Meritocracy
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1MGD
#     Title:  Writing & Rhetoric 1: Who Speaks for Nature? Rhetorics of Environmentalism and Justice
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1MO
#     Title:  Writing & Rhetoric 1: Imagining Technology: The Rhetoric of Humans and Machines
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1PB
#     Title:  Writing & Rhetoric 1:  Supreme Court Rhetoric
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1RC
#     Title:  Writing & Rhetoric 1: Domestication: How Humans Shape the Natural World
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1RHA
#     Title:  Writing & Rhetoric 1: The Rhetoric of Writing
#     Terms:  Spr Aut, Win, Spr
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter (ABCD/NP)
#  - PWR 1RHB
#     Title:  Writing & Rhetoric 1: The Rhetoric of Research
#     Terms:  not given this year Aut, Win, Spr
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter (ABCD/NP)
#  - PWR 1RHC
#     Title:  PWR 1RHC - Writing & Rhetoric 1: The Rhetoric of Composition Writing & Rhetoric 1: The Rhetoric of Composition
#     Terms:  not given this year Aut, Win, Spr
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter (ABCD/NP)
#  - PWR 1RHD
#     Title:  Writing & Rhetoric 1: The Rhetoric of Communication
#     Terms:  not given this year Aut, Win, Spr
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter (ABCD/NP)
#  - PWR 1RY
#     Title:  Writing & Rhetoric 1: From Hero to Celebrity: The Rhetoric of Fame
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1SBB
#     Title:  Writing & Rhetoric 1: The Rhetoric of Robots, Cyborgs, Mutants and Other Posthumans
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1SC
#     Title:  Writing & Rhetoric 1: Banksy, B-girls, and the Rhetoric of Public Art
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1SEA
#     Title:  Writing & Rhetoric 1: Cross-Cultural Rhetorics: Writing About Cultures and Communities Around Us
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1SHA
#     Title:  Writing & Rhetoric 1: Bench to Byline: The Life of Scientific Facts
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1SN
#     Title:  Writing & Rhetoric 1: The Rhetoric of Containment: Cold War Ideology Post 9/11
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1SR
#     Title:  Writing & Rhetoric 1: The Rhetoric of California
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1ST
#     Title:  Writing & Rhetoric 1:  The Rhetoric of Biomedical Ethics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1TB
#     Title:  Writing & Rhetoric 1: Hashtag Activism
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1TSC
#     Title:  Writing & Rhetoric 1: Academia Unleashed: Contemporary Rhetorics of Higher Education
#     Terms:  None Aut, Win
#     Units:  None 4
#     UG Reqs:  None Writing 1
#     Grading:  None Letter (ABCD/NP)
#  - PWR 1VK
#     Title:  Writing & Rhetoric 1: Rhetorics of Trauma
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1WG
#     Title:  Writing & Rhetoric 1:  Reading Minds: The Rhetoric of Consciousness
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1WS
#     Title:  PWR 1 Studio
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 1YZ
#     Title:  Writing & Rhetoric 1: In the Eyes of Different Beholders: Rhetoric of Beauty across Cultures
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2AB
#     Title:  Writing & Rhetoric 2: Makers, Crafters, Hackers: The Rhetoric of DIY
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2AG
#     Title:  Writing & Rhetoric 2: The Rhetoric of Film Criticism
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2AH
#     Title:  Writing & Rhetoric 2:  Ethnic Narratives and the Rhetoric of American Identity
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2ANA
#     Title:  Writing & Rhetoric 2: The Message in the Music
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2BRC
#     Title:  Writing & Rhetoric 2: Re-Make It Anew: The Rhetoric of Adapting, Rebooting, and Remaking
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2CA
#     Title:  Writing & Rhetoric 2: Networked Rhetoric: Communities, Collaboration, and Communication
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2CL
#     Title:  Writing & Rhetoric 2: Crime, Media & Law: Critical Approaches to Violence
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2CWB
#     Title:  Writing & Rhetoric 2: Hear/Say: The Art of Rhetorical Listening
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2DHA
#     Title:  Writing & Rhetoric 2:  Action Research: Making Time for Social Justice
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2DHB
#     Title:  Writing & Rhetoric 2: Feel Me? The Rhetoric, Practice and Complication of Empathy
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2EE
#     Title:  Writing & Rhetoric 2:  Once Upon a Cause: Producing Picture Books for Local Children
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2EPC
#     Title:  Writing & Rhetoric 2: Building Resilience: Writing Science, Policy and Community For a Better World
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2GAW
#     Title:  Writing & Rhetoric 2:  'Don't Stand so Close to Me' : Cross-cultural Communication
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2GME
#     Title:  Writing & Rhetoric 2: Our America: Conviction, Passion, Paranoia
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2IY
#     Title:  Writing & Rhetoric 2: Many Faces of Sherlock: Race, Gender, Power, and the Rhetoric of the Detective
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2JDC
#     Title:  Writing & Rhetoric 2: The Rhetoric of Collaboration: From Fandoms to Entrepreneurs
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2JJ
#     Title:  Writing & Rhetoric 2: The Rhetoric of Language, Identity and Power
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2JPA
#     Title:  Writing & Rhetoric 2: How We Got Schooled: The Rhetoric of Literacy and Education
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2JS
#     Title:  Writing & Rhetoric 2: In Science We Trust
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2KDB
#     Title:  Writing & Rhetoric 2: This is America: Virals, Videos and Values
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2KSB
#     Title:  Writing & Rhetoric 2:  Design Thinking:  Bringing d.thinking to Research, Writing & Presentation
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2KTA
#     Title:  Writing & Rhetoric 2: A Rebel With A Cause: The Rhetoric of Giving a Damn
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2LFA
#     Title:  Writing & Rhetoric 2: Unruly Bodies: Gesturing Toward a New Rhetorics of Body Language
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2LS
#     Title:  Writing & Rhetoric 2: The Rhetoric of Comics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2MGD
#     Title:  Writing & Rhetoric 2: Silicon Valley and the Future of Work: Rhetoric of Labor Utopias and Dystopias
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2MGE
#     Title:  Writing & Rhetoric 2: Rationality and Culture: Rhetorics of Reason, Madness, and Science
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2NF
#     Title:  Writing & Rhetoric 2: Language Gone Viral: Investigating the Rhet. of Social Media and Digital Comm.
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2PBB
#     Title:  Writing & Rhetoric 2: Mindful Rhetoric
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2PBC
#     Title:  Writing and Rhetoric 2: Why Do Geniuses Come in all Sizes, Shapes, and Colors?
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2RC
#     Title:  Writing & Rhetoric 2: Red Pill or Blue Pill? : The Rhetoric of Drugs
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2RHA
#     Title:  Writing & Rhetoric 2: The Rhetoric of Composition
#     Terms:  not given this year Aut, Win, Spr
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter (ABCD/NP)
#  - PWR 2RHB
#     Title:  Writing & Rhetoric 2: The Rhetoric of Presentation
#     Terms:  not given this year Aut, Win, Spr
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter (ABCD/NP)
#  - PWR 2RHC
#     Title:  Writing & Rhetoric 1: The Rhetoric of Speaking
#     Terms:  not given this year Aut, Win, Spr
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter (ABCD/NP)
#  - PWR 2RHD
#     Title:  Writing & Rhetoric 2: The Rhetoric of Argument
#     Terms:  not given this year Aut, Win, Spr
#     Units:  4
#     UG Reqs:  None
#     Grading:  Letter (ABCD/NP)
#  - PWR 2RL
#     Title:  Writing & Rhetoric 2: The Rhetoric of the Natural and Beyond
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2SBA
#     Title:  Writing & Rhetoric 2: The Rhetoric of Human Enhancement
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2SCB
#     Title:  Writing & Rhetoric 2: Bodies in the 21st Century: Gender and Rhetoric
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2SE
#     Title:  Writing & Rhetoric 2: Global Literacy and Visual Rhetorics
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2SN
#     Title:  Writing & Rhetoric 2: Rhetoric of Activism
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2SPB
#     Title:  Writing & Rhetoric 2: Hope, Health, and Healing: The Rhetoric of Medicine
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2SR
#     Title:  Writing & Rhetoric 2: The Rhetoric of Voice
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2STA
#     Title:  Writing & Rhetoric 2: Ethics and AI
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2TB
#     Title:  Writing & Rhetoric 2: Hip Hop, Orality, and Dialect Diversity
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2TSC
#     Title:  Writing & Rhetoric 2: All the Feels: The Rhetoric of Emotion
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2VK
#     Title:  Writing & Rhetoric 2: Framing Reality: The Rhetoric of Documentaries
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 2WG
#     Title:  Writing & Rhetoric 2:  All That Jazz: The Rhetoric of American Musical Theater
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 5
#     Title:  Independent Writing
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 6
#     Title:  Writing Workshop
#     Terms:  Aut, Win, Spr
#     Units:  1-3
#     UG Reqs:  None
#     Grading:  Satisfactory/No Credit
#  - PWR 91JS
#     Title:  Intermediate Writing: Stanford Science Podcast (EARTHSYS 157)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 91NSC
#     Title:  Intermediate Writing: Introduction to Science Communication
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 91OID
#     Title:  Creating Your Digital Story: Learn How to Build Your Online Identity and Why it Matters Creating Your Digital Presence: Learn How to Build Your Online Identity and Why it Matters
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 91SP
#     Title:  Intermediate Writing: Doctors' Stories: The Rhetoric of Illness and Healing
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 99A
#     Title:  Portfolio Preparation I
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 99B
#     Title:  Portfolio Preparation II
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 194EP
#     Title:  Topics in Writing & Rhetoric: Introduction to Environmental Justice: Race, Class, Gender and Place (CSRE 132E, EARTHSYS 194, URBANST 155EP)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 195
#     Title:  Writing Center Peer Tutor Seminar (PWR 295)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
#  - PWR 295
#     Title:  Writing Center Peer Tutor Seminar (PWR 195)
#     Terms:  None
#     Units:  None
#     UG Reqs:  None
#     Grading:  None
